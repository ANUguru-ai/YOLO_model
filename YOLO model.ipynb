# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/darknet'
# Out:
# /content/drive/My Drive/darknet

# %%
# !unzip training.zip

# %%
# !sed -i 's/OPENCV=1/OPENCV=0/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile

# %%
# !cat Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=0
# OPENCV=0
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
#
# DEBUG=0
#
# ARCH= -gencode arch=compute_30,code=sm_30 \
#       -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	  -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # Tesla V100
# # ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]
#
# # GeForce RTX 2080 Ti, RTX 2080, RTX 2070, Quadro RTX 8000, Quadro RTX 6000, Quadro RTX 5000, Tesla T4, XNOR Tensor Cores
# # ARCH= -gencode arch=compute_75,code=[sm_75,compute_75]
#
# # Jetson XAVIER
# # ARCH= -gencode arch=compute_72,code=[sm_72,compute_72]
#
# ...

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ...

# %%
# %cd ../
# Out:
# /content/drive/My Drive/darknet

# %%
# !unzip training.zip

# %%
# %cd img
# !ls
# Out:
# /content/drive/My Drive/darknet/img
# cardboard100.jpg  cardboard335.txt  cardboard91.txt  glass18.txt  glass42.jpg
# cardboard100.txt  cardboard337.jpg  cardboard92.jpg  glass1.jpg   glass42.txt
# cardboard309.jpg  cardboard337.txt  cardboard92.txt  glass1.txt   glass44.jpg
# cardboard309.txt  cardboard339.jpg  cardboard93.jpg  glass20.jpg  glass44.txt
# cardboard311.jpg  cardboard339.txt  cardboard93.txt  glass20.txt  glass46.jpg
# cardboard311.txt  cardboard342.jpg  cardboard94.jpg  glass22.jpg  glass46.txt
# cardboard313.jpg  cardboard342.txt  cardboard94.txt  glass22.txt  glass48.jpg
# cardboard313.txt  cardboard368.jpg  cardboard95.jpg  glass24.jpg  glass48.txt
# cardboard315.jpg  cardboard368.txt  cardboard95.txt  glass24.txt  glass4.jpg
# cardboard315.txt  cardboard370.jpg  cardboard96.jpg  glass26.jpg  glass4.txt
# cardboard317.jpg  cardboard370.txt  cardboard96.txt  glass26.txt  glass50.jpg
# cardboard317.txt  cardboard372.jpg  cardboard97.jpg  glass28.jpg  glass50.txt
# ...

# %%
import glob, os

# Current directory
current_dir = current_dir = os.getcwd()

print(current_dir)

current_dir = '/content/drive/My Drive/darknet/sft'

# Directory where the data will reside, relative to 'darknet.exe'
#path_data = './NFPAdataset/'

# Percentage of images to be used for the test set
percentage_test = 10;

# Create and/or truncate train.txt and test.txt
file_train = open('train.txt', 'w')
file_test = open('test.txt', 'w')

# Populate train.txt and test.txt
counter = 1
index_test = round(100 / percentage_test)
for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
    title, ext = os.path.splitext(os.path.basename(pathAndFilename))

    if counter == index_test:
        counter = 1
        file_test.write(current_dir + "/" + title + '.jpg' + "\n")
    else:
        file_train.write(current_dir + "/" + title + '.jpg' + "\n")
        counter = counter + 1
# Out:
# /content/drive/My Drive/darknet

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
# !wget https://pjreddie.com/media/files/yolov2.weights

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-03-09 07:35:39--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M   319KB/s    in 10m 27s
#
# 2020-03-09 07:46:08 (253 KB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# !wget https://pjreddie.com/media/files/darknet19_448.conv.23
# Out:
# --2019-08-06 09:55:19--  https://pjreddie.com/media/files/darknet19_448.conv.23
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79327120 (76M) [application/octet-stream]
# Saving to: ‘darknet19_448.conv.23’
#
# darknet19_448.conv. 100%[===================>]  75.65M  22.0MB/s    in 3.8s
#
# 2019-08-06 09:55:24 (19.9 MB/s) - ‘darknet19_448.conv.23’ saved [79327120/79327120]

# %%
# !./darknet partial extraction.cfg extraction.weights darknet19_448.conv.23

# %%
# %cd ..
# Out:
# /content/drive/My Drive/darknet

# %%
# !ls
# Out:
#  3rdparty		  darknet_video.py	  obj.data
#  appveyor.yml		  data			  obj.names
#  backup			  images		  README.md
#  bad_label.list		  images1		  results
#  build			  images1.zip		  scripts
#  build.ps1		  images.zip		  src
#  build.sh		  image_yolov2.sh	 'test (1).txt'
#  cardboard81.jpg	  image_yolov3.sh	 'train (1).txt'
#  cfg			  img			  training
#  classes.txt		  include		  training.zip
#  cmake			  json_mjpeg_streams.sh   video_v2.sh
#  CMakeLists.txt		  LICENSE		  video_yolov3.sh
#  darknet		  Makefile		  yolov2.cfg
#  darknet19_448.conv.23	  nandu			  yolov3.cfg
#  DarknetConfig.cmake.in   net_cam_v3.sh
#  darknet.py		  obj

# %%
# !./darknet detector train obj.data yolo-tiny.cfg darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# Region Avg IOU: 0.659627, Class: 0.998115, Obj: 0.895904, No Obj: 0.008271, Avg Recall: 1.000000,  count: 1
# Region Avg IOU: 0.685859, Class: 0.920403, Obj: 0.523939, No Obj: 0.005609, Avg Recall: 1.000000,  count: 1
#
#  5086: 0.204630, 0.503787 avg loss, 0.001000 rate, 0.375584 seconds, 81376 images
# Loaded: 0.000048 seconds
# Region Avg IOU: 0.810005, Class: 0.716420, Obj: 0.426008, No Obj: 0.006239, Avg Recall: 1.000000,  count: 2
# Region Avg IOU: 0.562117, Class: 0.975675, Obj: 0.868737, No Obj: 0.007123, Avg Recall: 1.000000,  count: 1
# Region Avg IOU: 0.718791, Class: 0.997326, Obj: 0.754950, No Obj: 0.005276, Avg Recall: 1.000000,  count: 1
# Region Avg IOU: 0.785022, Class: 0.998719, Obj: 0.818558, No Obj: 0.007457, Avg Recall: 1.000000,  count: 1
# Region Avg IOU: 0.826434, Class: 0.995913, Obj: 0.923484, No Obj: 0.007242, Avg Recall: 1.000000,  count: 1
# ...

# %%
# !./darknet detector test obj.data yolo-obj.cfg backup/yolo-obj_4000.weights pla.jpg
# Out:
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max               2 x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max               2 x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max               2 x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#    8 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#    9 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   10 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
# ...

# %%
# !./darknet detector demo obj.data yolo-obj.cfg backup/yolo-obj_1000.weights
# Out:
# Demo needs OpenCV for webcam images.

# %%
from google.colab import files
files.download('predictions.jpg')
